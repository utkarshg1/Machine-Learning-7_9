# %% [markdown]
# # Test File for Github

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ### Read the tips dataset

# %%
import pandas as pd
df = pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# ### Checking missing values in DataFrame

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# ### Visualisation

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['sex'].value_counts().plot(kind='bar', title='Countplot for Gender', figsize=(16,8))
# Out:
# <Axes: title={'center': 'Countplot for Gender'}, xlabel='sex'>

# %% [markdown]
# ### Plot Histogram for tips columns

# %%
import seaborn as sns
sns.histplot(data=df, x='tip', kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Get the pairplot

# %%
sns.pairplot(data=df, hue='time')

# %%
sns.pairplot(data=df, hue='sex')

# %%
sns.pairplot(data=df, hue='day')

# %%
sns.pairplot(data=df, hue='size', palette='rainbow')
